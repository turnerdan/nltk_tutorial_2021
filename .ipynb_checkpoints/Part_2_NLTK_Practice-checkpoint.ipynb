# %%
## FOR GOOGLE COLAB
# If you are using Google Colab, first run the code cell below. You can run a cell by clicking in the cell and clicking on the arrow that appears on the left side of the cell. DO NOT run this cell if you are not using Google Colab.

# !wget "https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2021/master/shakespeare.txt"
# !wget "https://github.com/turnerdan/nltk_tutorial_2021/blob/master/shakespeare_raw.pkl?raw=true"
# !wget "https://github.com/turnerdan/nltk_tutorial_2021/blob/master/shakespeare_text.pkl?raw=true"
# !wget "https://github.com/turnerdan/nltk_tutorial_2021/blob/master/shakespeare_tokens.pkl?raw=true"
# !wget "https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2021/master/walden.txt"
# !wget "https://github.com/turnerdan/nltk_tutorial_2021/blob/master/walden_clean_tokens.pkl?raw=true"
# !wget "https://github.com/turnerdan/nltk_tutorial_2021/blob/master/walden_raw.pkl?raw=true"
# !wget "https://github.com/turnerdan/nltk_tutorial_2021/blob/master/walden_text.pkl?raw=true"
# Out:
# --2021-08-09 08:47:20--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/shakespeare.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5784660 (5.5M) [text/plain]
# Saving to: ‘shakespeare.txt.2’
#
# shakespeare.txt.2   100%[===================>]   5.52M  1.67MB/s    in 3.3s
#
# 2021-08-09 08:47:23 (1.67 MB/s) - ‘shakespeare.txt.2’ saved [5784660/5784660]
#
# --2021-08-09 08:47:24--  https://github.com/turnerdan/nltk_tutorial_2020/blob/master/shakespeare_raw.pkl?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/turnerdan/nltk_tutorial_2020/raw/master/shakespeare_raw.pkl [following]
# --2021-08-09 08:47:24--  https://github.com/turnerdan/nltk_tutorial_2020/raw/master/shakespeare_raw.pkl
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/shakespeare_raw.pkl [following]
# --2021-08-09 08:47:24--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/shakespeare_raw.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5619321 (5.4M) [application/octet-stream]
# Saving to: ‘shakespeare_raw.pkl?raw=true.1’
#
# shakespeare_raw.pkl 100%[===================>]   5.36M  2.24MB/s    in 2.4s
#
# 2021-08-09 08:47:27 (2.24 MB/s) - ‘shakespeare_raw.pkl?raw=true.1’ saved [5619321/5619321]
#
# --2021-08-09 08:47:27--  https://github.com/turnerdan/nltk_tutorial_2020/blob/master/shakespeare_text.pkl?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/turnerdan/nltk_tutorial_2020/raw/master/shakespeare_text.pkl [following]
# --2021-08-09 08:47:27--  https://github.com/turnerdan/nltk_tutorial_2020/raw/master/shakespeare_text.pkl
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/shakespeare_text.pkl [following]
# --2021-08-09 08:47:27--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/shakespeare_text.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14390490 (14M) [application/octet-stream]
# Saving to: ‘shakespeare_text.pkl?raw=true.1’
#
# shakespeare_text.pk 100%[===================>]  13.72M  2.36MB/s    in 6.2s
#
# 2021-08-09 08:47:34 (2.20 MB/s) - ‘shakespeare_text.pkl?raw=true.1’ saved [14390490/14390490]
#
# --2021-08-09 08:47:34--  https://github.com/turnerdan/nltk_tutorial_2020/blob/master/shakespeare_tokens.pkl?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/turnerdan/nltk_tutorial_2020/raw/master/shakespeare_tokens.pkl [following]
# --2021-08-09 08:47:34--  https://github.com/turnerdan/nltk_tutorial_2020/raw/master/shakespeare_tokens.pkl
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/shakespeare_tokens.pkl [following]
# --2021-08-09 08:47:34--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/shakespeare_tokens.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7615156 (7.3M) [application/octet-stream]
# Saving to: ‘shakespeare_tokens.pkl?raw=true.1’
#
# shakespeare_tokens. 100%[===================>]   7.26M  2.04MB/s    in 3.6s
#
# 2021-08-09 08:47:38 (2.00 MB/s) - ‘shakespeare_tokens.pkl?raw=true.1’ saved [7615156/7615156]
#
# --2021-08-09 08:47:38--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/walden.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584967 (571K) [text/plain]
# Saving to: ‘walden.txt.2’
#
# walden.txt.2        100%[===================>] 571.26K  1.57MB/s    in 0.4s
#
# 2021-08-09 08:47:39 (1.57 MB/s) - ‘walden.txt.2’ saved [584967/584967]
#
# --2021-08-09 08:47:39--  https://github.com/turnerdan/nltk_tutorial_2020/blob/master/walden_clean_tokens.pkl?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/turnerdan/nltk_tutorial_2020/raw/master/walden_clean_tokens.pkl [following]
# --2021-08-09 08:47:39--  https://github.com/turnerdan/nltk_tutorial_2020/raw/master/walden_clean_tokens.pkl
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/walden_clean_tokens.pkl [following]
# --2021-08-09 08:47:40--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/walden_clean_tokens.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 774693 (757K) [application/octet-stream]
# Saving to: ‘walden_clean_tokens.pkl?raw=true.1’
#
# walden_clean_tokens 100%[===================>] 756.54K  2.15MB/s    in 0.3s
#
# 2021-08-09 08:47:40 (2.15 MB/s) - ‘walden_clean_tokens.pkl?raw=true.1’ saved [774693/774693]
#
# --2021-08-09 08:47:40--  https://github.com/turnerdan/nltk_tutorial_2020/blob/master/walden_raw.pkl?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/turnerdan/nltk_tutorial_2020/raw/master/walden_raw.pkl [following]
# --2021-08-09 08:47:41--  https://github.com/turnerdan/nltk_tutorial_2020/raw/master/walden_raw.pkl
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/walden_raw.pkl [following]
# --2021-08-09 08:47:41--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/walden_raw.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584256 (571K) [application/octet-stream]
# Saving to: ‘walden_raw.pkl?raw=true.1’
#
# walden_raw.pkl?raw= 100%[===================>] 570.56K  2.19MB/s    in 0.3s
#
# 2021-08-09 08:47:41 (2.19 MB/s) - ‘walden_raw.pkl?raw=true.1’ saved [584256/584256]
#
# --2021-08-09 08:47:41--  https://github.com/turnerdan/nltk_tutorial_2020/blob/master/walden_text.pkl?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/turnerdan/nltk_tutorial_2020/raw/master/walden_text.pkl [following]
# --2021-08-09 08:47:42--  https://github.com/turnerdan/nltk_tutorial_2020/raw/master/walden_text.pkl
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/walden_text.pkl [following]
# --2021-08-09 08:47:42--  https://raw.githubusercontent.com/turnerdan/nltk_tutorial_2020/master/walden_text.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1526466 (1.5M) [application/octet-stream]
# Saving to: ‘walden_text.pkl?raw=true.1’
#
# walden_text.pkl?raw 100%[===================>]   1.46M  1.58MB/s    in 0.9s
#
# 2021-08-09 08:47:43 (1.58 MB/s) - ‘walden_text.pkl?raw=true.1’ saved [1526466/1526466]

# %%
#######################
## Setup environment ##
#######################

# Import packages
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
from scipy import special
from nltk import *
from nltk.corpus import stopwords

# %% [markdown]
# # Tokenize Shakespeare
#
# **Tokenize The Complete Works of William Shakespeare.**
#
# * Below I give the filepath to a plaintext version of the complete works of William Shakespeare.
#
# * Keep in mind that it will take a little while to run these scripts because this text file is larger than Walden.
# * Tokenization takes about 10 seconds and cleaning + plotting takes about two minutes.
#
# Answers are in the repository.

# %%
##################################################################
## ## ## ## > Code it < ## ## ## ##                              #
################################### "Cleaning_Shakespeare_Timed" #
## Sample answer in /answer_keys ##                              #
##################################################################

######################
## Read-in the file ##
######################

# What is the path to the complete works of Shakespeare?
shakespeare_path = 'shakespeare.txt'

# Open the file at the specified path
shakespeare_file = open( shakespeare_path, 'r')

# Read the file as raw text by calling the file with the read() function
shakespeare_raw = 

# Close the original file with the close() function
shakespeare_file.close()

#######################
## Tokenize the file ##
#######################

# Tokenize the raw text using word_tokenize()
shakespeare_tokens = 

# Print a list of the tokens
# Out:
#   File "<ipython-input-5-844fc660ec7f>", line 18
#     shakespeare_raw =
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Plot the token frequency distribution for Shakespeare
#
# **Plot the 50 most frequent tokens in the complete works of William Shakespeare.**

# %%
##############
## Cleaning ##
##############

# Remove non-alphabetical characters using list comprehension
shakespeare_tokens = [ token for token in shakespeare_tokens if token.isalpha() ]

# Convert the text to lowercase using list comprehension
shakespeare_tokens = [ token.lower() for token in shakespeare_tokens ]

# Filter out stopwords using list comprehension
shakespeare_tokens = [token for token in shakespeare_tokens if not token in set(stopwords.words('english'))]

####################
## Frequency plot ##
####################

# Generate a frequency distribution for the tokens


# Display plot with top 50 tokens
